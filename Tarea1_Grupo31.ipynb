# %% [markdown]
# # Tarea 1 Bases de Datos 2023-1 Grupo 31

# %% [markdown]
# ## Integrantes:
# * Agustín Aravena - 202173022-2
# * Sofía Meléndez - 202173041-9

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql
! pip3 install psycopg2

#Use to generate names
! pip3 install names
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython-sql in c:\users\sofia\appdata\roaming\python\python311\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (3.6.0)
# Requirement already satisfied: ipython in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (8.11.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (2.0.8)
# Requirement already satisfied: sqlparse in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: six in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.2)
# Requirement already satisfied: backcall in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: colorama in c:\users\sofia\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\sofia\appdata\roaming\python\python311\site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sofia\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\sofia\appdata\roaming\python\python311\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2 in c:\users\sofia\appdata\roaming\python\python311\site-packages (2.9.6)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: names in c:\users\sofia\appdata\roaming\python\python311\site-packages (0.3.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importar dependencias

# %%
from datetime import datetime
import random as r
import names

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:password@localhost:5432/dbname
# Out:
# env: DATABASE_URL=postgresql://postgres:Hogwartsismyhome.07@localhost:5432/tarea1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
connection = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='dbname',
   password="password"
)

print(connection)
cursor = connection.cursor()
# Out:
# <connection object at 0x00000269840D2F00; dsn: 'user=postgres password=xxx dbname=tarea1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas (36 pts.)
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "facciones" (6 pts)

# %%
# %%sql
# CREATE TABLE facciones (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     descripcion VARCHAR(45) NOT NULL,
#     PRIMARY KEY (id)
# );
# Out:
# (psycopg2.errors.DuplicateTable) la relación «facciones» ya existe
#
# [SQL: CREATE TABLE facciones (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     descripcion VARCHAR(45) NOT NULL,
#     PRIMARY KEY (id)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "trabajos" (6 pts)

# %%
# %%sql
# CREATE TABLE trabajos(
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     descripcion VARCHAR(45) NOT NULL,
#     sueldo INTEGER NOT NULL,
#     PRIMARY KEY (id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# (psycopg2.errors.DuplicateTable) la relación «trabajos» ya existe
#
# [SQL: CREATE TABLE trabajos(
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     descripcion VARCHAR(45) NOT NULL,
#     sueldo INTEGER NOT NULL,
#     PRIMARY KEY (id)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "personas" (6 pts)

# %%
# %%sql
# CREATE TABLE personas (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellidos VARCHAR(45) NOT NULL,
#     fecha_nacimiento DATE NOT NULL,
#     infectado BOOLEAN NOT NULL,
#     conyugue INTEGER,
#     PRIMARY KEY (id),
#     FOREIGN KEY (conyugue) REFERENCES personas(id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# (psycopg2.errors.DuplicateTable) la relación «personas» ya existe
#
# [SQL: CREATE TABLE personas (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellidos VARCHAR(45) NOT NULL,
#     fecha_nacimiento DATE NOT NULL,
#     infectado BOOLEAN NOT NULL,
#     conyugue INTEGER,
#     PRIMARY KEY (id),
#     FOREIGN KEY (conyugue) REFERENCES personas(id)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "cuentas_bancarias" (6 pts)

# %%
# %%sql
# CREATE TABLE cuentas_bancarias (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     tipo_de_cuenta VARCHAR(45) NOT NULL,
#     banco VARCHAR(45) NOT NULL,
#     saldo INTEGER NOT NULL,
#     id_persona INTEGER NOT NULL,
#     PRIMARY KEY (id),
#     FOREIGN KEY (id_persona) REFERENCES personas (id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# (psycopg2.errors.DuplicateTable) la relación «cuentas_bancarias» ya existe
#
# [SQL: CREATE TABLE cuentas_bancarias (
#     id INTEGER GENERATED ALWAYS AS IDENTITY,
#     tipo_de_cuenta VARCHAR(45) NOT NULL,
#     banco VARCHAR(45) NOT NULL,
#     saldo INTEGER NOT NULL,
#     id_persona INTEGER NOT NULL,
#     PRIMARY KEY (id),
#     FOREIGN KEY (id_persona) REFERENCES personas (id)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "persona_pertenece_faccion" (6 pts)

# %%
# %%sql
# CREATE TABLE persona_pertenece_faccion(
#     id_persona INTEGER,
#     id_faccion INTEGER,
#     CONSTRAINT persona_pertenece_faccion_PK PRIMARY KEY (id_persona,id_faccion),
#     CONSTRAINT persona_pertenece_faccion_FK1 FOREIGN KEY (id_persona) REFERENCES personas(id),
#     CONSTRAINT persona_pertenece_faccion_FK2 FOREIGN KEY (id_faccion) REFERENCES facciones(id)
#     );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "persona_tiene_trabajo" (6 pts)

# %%
# %%sql
# CREATE TABLE persona_tiene_trabajo(
#     id_persona INTEGER,
#     id_trabajo INTEGER,
#     estado BOOLEAN NOT NULL,
#     ultima_vez_realizado TIMESTAMP NOT NULL,
#     CONSTRAINT persona_tiene_trabajo_PK PRIMARY KEY (id_persona,id_trabajo),
#     CONSTRAINT persona_tiene_trabajo_FK1 FOREIGN KEY (id_persona) REFERENCES personas(id),
#     CONSTRAINT persona_tiene_trabajo_FK2 FOREIGN KEY (id_trabajo) REFERENCES trabajos(id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.
#
# PD: Si el codigo tira error por "violar la unicidad de las PK" es por una coincidencia de numeros random, solamente volver a ejecutar el codigo

# %%
#Recuerde haber ejecutado todas las celdas anteriores!

# Generador de timestamp aleatorio.
def generate_timestamp_nacimiento():
    year = r.randint(1970,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

def generate_timestamp_trabajo():
    year = r.randint(2019,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

print("Borrando Datos Antiguos...")

# Limpia la base de datos.
connection.commit() # En caso de algun error
query = 'TRUNCATE TABLE "facciones", "trabajos", "personas", "cuentas_bancarias", "persona_pertenece_faccion", "persona_tiene_trabajo" RESTART IDENTITY'
cursor.execute(query)
connection.commit()

print("Generando Datos...")

facciones = [("FEDRA", "La Agencia Federal de Respuesta a Desastres"), ("Luciérnagas", "Grupo de milicias revolucionario"), ("Carroñeros", "Sin identificación"), ("Pythonia", "Grupo defensor de la libertad"), ("MaCdonia", "Los exiliados de la carceles"), ("JavaScriptia", "Grupo defensor de la paz")]
trabajos = [("Limpieza", "Encargado de limpiar las calles"),
("Limpiador de cloacas","Encargado de limpiar las cloacas"),
("Militar","Encargado de proteger la ciudad"),
("Explorador","Encargado de explorar la ciudad"),
("Médico","encargado de curar a los enfermos"),
("Profesor","Encargado de enseñar a los niños"),
("Cremador","Encargado de quemar los cadáveres"),
("Científico","Encargado de investigar"),
("Cocinero","Encargado de cocinar"),
("Carpintero","Encargado de construir"),
("Cerrajero","Encargado de reparar las cerraduras"),
("Cartero","Encargado de repartir los correos"),
("Cajero","Encargado de cobrar los impuestos")]
tipos_de_cuenta_bancaria = ["Cuenta Vista", "Cuenta Ahorro", "Cuenta Corriente", "Cuenta RUT", "Cuenta de Inversion", "Cuenta PrePago", "Cuenta de Credito"]
bancos = ["FedraBank S.A", "Banco Pedrito Pascal SpA", "Banco Pythonia S.A", "Banco de la Nación S.A", "Banco Santander SpA", "Banco BCI SpA", "Banco Estado SpA", "Banco Consorcio S.A", "Banco BBVA", "Banco Scotiabank"]

# Variables.
n_facciones = len(facciones)
n_trabajos = len(trabajos)
n_personas = 1000
n_cuentas_bancarias = 120
n_persona_pertenece_faccion = 300
n_persona_tiene_trabajo = 300
n_casados = 100

# Genera personas.
personas = []
for _ in range(n_personas):
    nombre = names.get_first_name()
    apellidos = names.get_last_name()+" "+names.get_last_name()
    fecha_nacimiento = generate_timestamp_nacimiento()
    infectado = r.choice([True, False])
    
    personas.append((nombre, apellidos, fecha_nacimiento, infectado, None))


# Genera cuentas bancarias.
cuentas_bancarias = []
for _ in range(n_cuentas_bancarias):
    tipo_de_cuenta = r.choice(tipos_de_cuenta_bancaria)
    banco = r.choice(bancos)
    saldo = r.randint(0, 10000)
    id_persona = r.choice(range(1, n_personas+1))
    
    cuentas_bancarias.append((tipo_de_cuenta, banco, saldo, id_persona))
    
    
# Generate persona_pertenece_faccion.
persona_pertenece_faccion = set([(r.choice(range(1, n_personas+1)), r.choice(range(1, n_facciones+1))) for _ in range(1, n_persona_pertenece_faccion+1)])

# Generate persona_tiene_trabajo.
persona_tiene_trabajo_prev = set([(r.choice(range(1, n_personas+1)), r.choice(range(1, n_trabajos+1))) for _ in range(1, n_persona_tiene_trabajo+1)])
persona_tiene_trabajo = [(id_persona, id_trabajo, r.choice([True, False]), generate_timestamp_trabajo()) for id_persona, id_trabajo in persona_tiene_trabajo_prev]
    
# SQL Statements.
inserts = [
    'INSERT INTO "facciones" ("nombre", "descripcion") VALUES (%s, %s);',
    'INSERT INTO "trabajos" ("nombre", "descripcion", "sueldo") VALUES (%s, %s, %s);',
    'INSERT INTO "personas" ("nombre", "apellidos", "fecha_nacimiento", "infectado", "conyugue") VALUES (%s, %s, %s, %s, %s);',
    'INSERT INTO "cuentas_bancarias" ("tipo_de_cuenta", "banco", "saldo", "id_persona") VALUES (%s, %s, %s, %s);',
    'INSERT INTO "persona_pertenece_faccion" ("id_persona", "id_faccion") VALUES (%s, %s);',
    'INSERT INTO "persona_tiene_trabajo" ("id_persona", "id_trabajo", "estado", "ultima_vez_realizado") VALUES (%s, %s, %s, %s);'
]

for faccion in facciones:
    cursor.execute(inserts[0], faccion)

for trabajo in trabajos:
    t = (trabajo[0], trabajo[1], r.randint(100, 5000))
    cursor.execute(inserts[1], t)

# Crear una lista con personas casadas y otra con personas solteras. donde se cambie la ide de la persona que se casó.

for persona in personas:
    cursor.execute(inserts[2], persona)
    
for cb in cuentas_bancarias:
    cursor.execute(inserts[3], cb)

for ppf in persona_pertenece_faccion:
    cursor.execute(inserts[4], ppf)
    
for ptt in persona_tiene_trabajo:
    cursor.execute(inserts[5], ptt)
    
connection.commit()


# Generar Matrimonios
n_repetidos = []

for i in range(n_casados):
    random = r.randint(1, n_personas)
    if random in n_repetidos:
        continue
    else:
        random2 = r.randint(1, n_personas)
        if random2 in n_repetidos:
            continue
        else:
            n_repetidos.append(random)
            n_repetidos.append(random2)
            cursor.execute("UPDATE personas SET conyugue = %s WHERE id = %s", (random2, random))
            cursor.execute("UPDATE personas SET conyugue = %s WHERE id = %s", (random, random2))
            connection.commit()

print("Todo Listo!")
# Out:
# Borrando Datos Antiguos...
# Generando Datos...
# Todo Listo!

# %% [markdown]
# ## Consultas (64 pts.)
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1 (6 pts)
# **ID, nombre y primer apellido de los habitantes de FEDRA**
#
# Ejemplo:
#
# |ID |  Nombre      |  Apellido  |
# |---|-----------|-----------|
# | 12 |Joel | Miller |
# |21 | Ellie | Williams |
# | ... | ... | ... |
#
# **Solución:** Seleccionamos el id, el nombre y los apellidos de la tabla persona. Para poder tener solo el primer apellido usamos la funcion left() y la funcion position(), la funcion position es para que cuando identifique un espacio lo que le sigue no se agregue a la columna apellido.

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     id AS "ID",
#     nombre AS "Nombre",
#     left(apellidos, position(' ' in apellidos)) AS "Apellido"
# FROM
#     personas
# ORDER BY
#     id ASC
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 1000 rows affected.
# [(1, 'Myrtis', 'Lynum '),
#  (2, 'Heather', 'Nolin '),
#  (3, 'Shane', 'Rozanski '),
#  (4, 'Victoria', 'Stafford '),
#  (5, 'Hazel', 'Hartel '),
#  (6, 'Justin', 'Carney '),
#  (7, 'Michell', 'Gonser '),
#  (8, 'Teresa', 'Session '),
#  (9, 'Elizabeth', 'Addams '),
#  (10, 'Julian', 'Kay '),
#  (11, 'Shelly', 'Myott '),
#  (12, 'Maria', 'Piccinone '),
#  (13, 'Myrtle', 'Mcclaskey '),
#  (14, 'Joann', 'Moran '),
#  (15, 'August', 'Smith '),
#  (16, 'Nicole', 'Tartaglione '),
#  (17, 'Phillip', 'Newcomb '),
#  (18, 'Sheri', 'Testa '),
#  (19, 'Elizabeth', 'Howell '),
#  (20, 'Maria', 'Hartman '),
#  (21, 'William', 'Gardner '),
#  (22, 'Raymond', 'Raybuck '),
#  (23, 'Philip', 'Montoya '),
#  (24, 'Brenda', 'Basham '),
#  (25, 'Katherine', 'Beaudoin '),
#  (26, 'Paul', 'Newsome '),
#  (27, 'Joseph', 'Skaggs '),
#  (28, 'Benjamin', 'Mcnally '),
#  (29, 'Thomas', 'Patterson '),
#  (30, 'Leroy', 'Frederick '),
#  (31, 'Ramon', 'Wilhelm '),
#  (32, 'Dolores', 'Randall '),
#  (33, 'Suzanne', 'Babb '),
#  (34, 'Lisa', 'Schmalz '),
#  (35, 'Neal', 'Force '),
#  (36, 'Dina', 'Turner '),
#  (37, 'Robert', 'Garza '),
#  (38, 'William', 'Starr '),
#  (39, 'Christopher', 'Babbitt '),
#  (40, 'Katrina', 'Shorey '),
#  (41, 'Edward', 'Lowe '),
#  (42, 'Christine', 'Beltran '),
#  (43, 'Randi', 'Navarro '),
#  (44, 'Carolyn', 'Kurz '),
#  (45, 'Mary', 'Peacock '),
#  (46, 'Rae', 'Reichman '),
#  (47, 'Hugh', 'Mintz '),
#  (48, 'Lizzie', 'Nicholson '),
#  (49, 'Patricia', 'Mansfield '),
#  (50, 'Amy', 'Mull '),
#  (51, 'Mary', 'Potter '),
#  (52, 'Clarence', 'Carrithers '),
#  (53, 'Vincent', 'Jones '),
#  (54, 'James', 'Hill '),
#  (55, 'Raul', 'Richardson '),
#  (56, 'Wallace', 'Baker '),
#  (57, 'Mark', 'Thomas '),
#  (58, 'Jordan', 'Edwards '),
#  (59, 'Jennifer', 'Wilson '),
#  (60, 'Tommy', 'Noonan '),
#  (61, 'Helen', 'Tademy '),
#  (62, 'Herman', 'Inoue '),
#  (63, 'Helen', 'Donohoe '),
#  (64, 'Norman', 'Cowger '),
#  (65, 'Carlos', 'Mckinney '),
#  (66, 'Cynthia', 'Minteer '),
#  (67, 'William', 'Carnahan '),
#  (68, 'Juan', 'Sheehy '),
#  (69, 'Stanley', 'Shannon '),
#  (70, 'Melissa', 'Spiney '),
#  (71, 'James', 'Gaylor '),
#  (72, 'Ronald', 'Kunz '),
#  (73, 'Laura', 'Connors '),
#  (74, 'Marvin', 'Hardy '),
#  (75, 'Kenneth', 'Goldstein '),
#  (76, 'Linda', 'Angeles '),
#  (77, 'Penny', 'Warriner '),
#  (78, 'Joseph', 'Hernandez '),
#  (79, 'Logan', 'Widner '),
#  (80, 'Mary', 'Jara '),
#  (81, 'Maria', 'Petrulis '),
#  (82, 'Terrance', 'Terepka '),
#  (83, 'June', 'Parks '),
#  (84, 'Chris', 'Muir '),
#  (85, 'Annie', 'Bonner '),
#  (86, 'Mary', 'Sherrod '),
#  (87, 'Aaron', 'Sundt '),
#  (88, 'Stuart', 'Ackerley '),
#  (89, 'Barbara', 'Ling '),
#  (90, 'Arthur', 'Mercurio '),
#  (91, 'Kevin', 'Jones '),
#  (92, 'Susie', 'Childs '),
#  (93, 'Larry', 'Barrie '),
#  (94, 'Maxine', 'Picou '),
#  (95, 'Robyn', 'Guy '),
#  (96, 'Edith', 'Stump '),
#  (97, 'Lucille', 'Mcdonald '),
#  (98, 'Barbara', 'Archer '),
#  (99, 'Andrea', 'Shaffer '),
#  (100, 'Michael', 'Tamayo '),
#  (101, 'Tammy', 'Baldwin '),
#  (102, 'Carol', 'Eugene '),
#  (103, 'Michael', 'Brissett '),
#  (104, 'Lauren', 'Benjamin '),
#  (105, 'Melissa', 'Barry '),
#  (106, 'Lottie', 'Munez '),
#  (107, 'John', 'Devine '),
#  (108, 'Dustin', 'Crawford '),
#  (109, 'Mitchell', 'Briney '),
#  (110, 'Roger', 'Gebhart '),
#  (111, 'Robert', 'Hoskins '),
#  (112, 'Guy', 'Merritt '),
#  (113, 'Velma', 'Pruchnik '),
#  (114, 'James', 'Saunders '),
#  (115, 'Rachelle', 'Emme '),
#  (116, 'Cody', 'Fox '),
#  (117, 'Edward', 'Tennant '),
#  (118, 'Melanie', 'Miley '),
#  (119, 'Ronald', 'Sloan '),
#  (120, 'Sara', 'Middleton '),
#  (121, 'Barbara', 'Mackinnon '),
#  (122, 'Nellie', 'Bonds '),
#  (123, 'Carlos', 'Breedlove '),
#  (124, 'William', 'Hyatt '),
#  (125, 'Christopher', 'Roberts '),
#  (126, 'Catherine', 'Richmond '),
#  (127, 'Latisha', 'Hawkins '),
#  (128, 'Lynn', 'Ashmore '),
#  (129, 'Catherine', 'Bradley '),
#  (130, 'Leslie', 'Hendricks '),
#  (131, 'James', 'Laplante '),
#  (132, 'Gary', 'Robinson '),
#  (133, 'Paul', 'Campbell '),
#  (134, 'Howard', 'Vasquez '),
#  (135, 'Carol', 'Keeling '),
#  (136, 'Georgia', 'Burton '),
#  (137, 'Henry', 'Johnson '),
#  (138, 'Edward', 'Byrd '),
#  (139, 'Richard', 'Samayoa '),
#  (140, 'Keith', 'Dorsey '),
#  (141, 'Moises', 'Shields '),
#  (142, 'Michael', 'Ford '),
#  (143, 'Mark', 'Smith '),
#  (144, 'Katina', 'Hickling '),
#  (145, 'Samantha', 'Cross '),
#  (146, 'Jake', 'Wheeler '),
#  (147, 'Carolyn', 'Cox '),
#  (148, 'Elizabeth', 'Green '),
#  (149, 'Maude', 'Caverly '),
#  (150, 'David', 'Bacon '),
#  (151, 'Joseph', 'Major '),
#  (152, 'Krystle', 'Robinson '),
#  (153, 'Dorothy', 'Kramer '),
#  (154, 'Jesse', 'Blazer '),
#  (155, 'Mary', 'Lopez '),
#  (156, 'Nicholas', 'Anderson '),
#  (157, 'Chris', 'Hurley '),
#  (158, 'Richard', 'Seay '),
#  (159, 'Ann', 'Sachs '),
#  (160, 'Ursula', 'Wright '),
#  (161, 'Carolyn', 'Ryan '),
#  (162, 'Nancy', 'Ellis '),
#  (163, 'Noemi', 'Rhoda '),
#  (164, 'Robert', 'Mobley '),
#  (165, 'Tina', 'Benavides '),
#  (166, 'Anthony', 'Priddy '),
#  (167, 'Betty', 'Flores '),
#  (168, 'Roxanne', 'Henderson '),
#  (169, 'Evelyn', 'Vega '),
#  (170, 'Marie', 'Turner '),
#  (171, 'Eugenia', 'Bird '),
#  (172, 'Joan', 'English '),
#  (173, 'Carl', 'Baird '),
#  (174, 'Darrell', 'Chastain '),
#  (175, 'Theodore', 'Carey '),
#  (176, 'Erin', 'Miller '),
#  (177, 'John', 'Williams '),
#  (178, 'Jesus', 'Clarence '),
#  (179, 'Judy', 'Crabill '),
#  (180, 'Rosa', 'Shelton '),
#  (181, 'Patricia', 'Reed '),
#  (182, 'Michael', 'Sanchez '),
#  (183, 'Mary', 'Bray '),
#  (184, 'John', 'Filip '),
#  (185, 'Gloria', 'Davis '),
#  (186, 'Ramona', 'Pfundt '),
#  (187, 'Richard', 'Vera '),
#  (188, 'Rhonda', 'Simpson '),
#  (189, 'Freda', 'Gibson '),
#  (190, 'Mary', 'Harris '),
#  (191, 'Rosalyn', 'Nelson '),
#  (192, 'Dolores', 'Forsyth '),
#  (193, 'Joe', 'King '),
#  (194, 'Bernice', 'Thorne '),
#  (195, 'Paulette', 'Wise '),
#  (196, 'Margaret', 'Miranda '),
#  (197, 'Lakesha', 'Sylvain '),
#  (198, 'Molly', 'Swindell '),
#  (199, 'David', 'Burmside '),
#  (200, 'Shirley', 'Zajc '),
#  (201, 'Jessica', 'Pierce '),
#  (202, 'John', 'Jackson '),
#  (203, 'Hope', 'Carruth '),
#  (204, 'Virginia', 'Dunseith '),
#  (205, 'Sarah', 'Respess '),
#  (206, 'Steven', 'Furlow '),
#  (207, 'William', 'Morales '),
#  (208, 'Raul', 'Rodriquez '),
#  (209, 'Ezekiel', 'Mcmakin '),
#  (210, 'Joe', 'Thomas '),
#  (211, 'Rachel', 'Freeman '),
#  (212, 'Alexander', 'Watkin '),
#  (213, 'Sophie', 'Rodgers '),
#  (214, 'Brendan', 'Williams '),
#  (215, 'Kenneth', 'Beck '),
#  (216, 'Elizabeth', 'Limmel '),
#  (217, 'Samantha', 'Harris '),
#  (218, 'Sammy', 'Manor '),
#  (219, 'Thomas', 'Snider '),
#  (220, 'Doris', 'Wilkinson '),
#  (221, 'John', 'Brooks '),
#  (222, 'Cyril', 'Modica '),
#  (223, 'Kathy', 'Hensley '),
#  (224, 'Rick', 'Kendrick '),
#  (225, 'Katherine', 'Blazer '),
#  (226, 'Ruben', 'Diggs '),
#  (227, 'Anette', 'Gibson '),
#  (228, 'Thomas', 'Horton '),
#  (229, 'Dulce', 'Mclaughlin '),
#  (230, 'Antoinette', 'Hartman '),
#  (231, 'Debbie', 'Babb '),
#  (232, 'Ernestine', 'Gilmore '),
#  (233, 'Jonathan', 'Coates '),
#  (234, 'Catherine', 'Perez '),
#  (235, 'Richard', 'Henry '),
#  (236, 'Teddy', 'Almanza '),
#  (237, 'Joyce', 'Volk '),
#  (238, 'Mary', 'Sapp '),
#  (239, 'Wallace', 'Guillory '),
#  (240, 'Richard', 'Oakes '),
#  (241, 'Helen', 'Heifner '),
#  (242, 'Jennifer', 'Davis '),
#  (243, 'Denise', 'Miller '),
#  (244, 'Amy', 'Nelson '),
#  (245, 'Rosa', 'Spann '),
#  (246, 'Michael', 'Matherne '),
#  (247, 'David', 'Young '),
#  (248, 'Derek', 'Emmons '),
#  (249, 'Jean', 'Jones '),
#  (250, 'Richard', 'Fink '),
#  (251, 'Eliza', 'Simpson '),
#  (252, 'Pierre', 'Jones '),
#  (253, 'Terry', 'Adame '),
#  (254, 'Carlos', 'Nelson '),
#  (255, 'Marvin', 'Jeffers '),
#  (256, 'Keely', 'Curtis '),
#  (257, 'Meghan', 'Ecklund '),
#  (258, 'Kevin', 'Oconnor '),
#  (259, 'Celia', 'Smith '),
#  (260, 'Jeanelle', 'Ogburn '),
#  (261, 'Stephen', 'Stewart '),
#  (262, 'Kathy', 'Anderson '),
#  (263, 'Candi', 'Anderson '),
#  (264, 'Linda', 'Wolf '),
#  (265, 'John', 'Pfau '),
#  (266, 'Albert', 'Jackson '),
#  (267, 'Mary', 'Plummer '),
#  (268, 'Terry', 'Butcher '),
#  (269, 'Dorothy', 'Marinaccio '),
#  (270, 'Tommy', 'Hillsman '),
#  (271, 'Nannette', 'Nguyen '),
#  (272, 'Nicole', 'Jackson '),
#  (273, 'Leonard', 'Simon '),
#  (274, 'Cecil', 'Riggs '),
#  (275, 'Daniel', 'Dix '),
#  (276, 'Debra', 'Brandly '),
#  (277, 'Eddie', 'Mendez '),
#  (278, 'Vernon', 'Carr '),
#  (279, 'Ilene', 'Mcclanahan '),
#  (280, 'Stanley', 'Pollock '),
#  (281, 'Lisa', 'Bradley '),
#  (282, 'David', 'Douglas '),
#  (283, 'Christine', 'King '),
#  (284, 'Michelle', 'Kitchen '),
#  (285, 'Brandon', 'Jeansonne '),
#  (286, 'Joshua', 'Tanner '),
#  (287, 'Robert', 'Joseph '),
#  (288, 'Dolores', 'Pantoja '),
#  (289, 'Alicia', 'Dixon '),
#  (290, 'Luis', 'Stanfield '),
#  (291, 'Kimberly', 'Lewis '),
#  (292, 'Lori', 'Crosslin '),
#  (293, 'Nicholas', 'Benton '),
#  (294, 'John', 'Kennedy '),
#  (295, 'David', 'Mayberry '),
#  (296, 'Bertha', 'Duppstadt '),
#  (297, 'Jason', 'Pugh '),
#  (298, 'Linda', 'Trusty '),
#  (299, 'Dennis', 'Cummings '),
#  (300, 'Kate', 'Tuggle '),
#  (301, 'Mary', 'Chandler '),
#  (302, 'Luis', 'Kowalczyk '),
#  (303, 'Margarita', 'Mathis '),
#  (304, 'Robert', 'Hines '),
#  (305, 'Fred', 'Parlato '),
#  (306, 'John', 'Shaw '),
#  (307, 'Charles', 'Jackson '),
#  (308, 'Jeffrey', 'Beall '),
#  (309, 'John', 'Watts '),
#  (310, 'Barbara', 'Tellis '),
#  (311, 'Sergio', 'Forker '),
#  (312, 'Kevin', 'Worley '),
#  (313, 'Mary', 'King '),
#  (314, 'Georgia', 'Levay '),
#  (315, 'Jonnie', 'Bradley '),
#  (316, 'Carolyn', 'Mccall '),
#  (317, 'Floyd', 'Real '),
#  (318, 'David', 'Pinkowski '),
#  (319, 'Daniel', 'David '),
#  (320, 'Lezlie', 'Sanches '),
#  (321, 'Brandee', 'Whitehead '),
#  (322, 'Lillian', 'Stansberry '),
#  (323, 'Britney', 'Kelly '),
#  (324, 'Merle', 'Miller '),
#  (325, 'Michael', 'Hartsook '),
#  (326, 'Sonia', 'Gil '),
#  (327, 'Evelyn', 'Hesley '),
#  (328, 'Wilma', 'Thornton '),
#  (329, 'Dan', 'Grubb '),
#  (330, 'Melody', 'Whitley '),
#  (331, 'Karen', 'Wiesner '),
#  (332, 'Moses', 'Hill '),
#  (333, 'Aida', 'Rios '),
#  (334, 'Guy', 'Merritt '),
#  (335, 'Mohammed', 'Sease '),
#  (336, 'Dorothy', 'Valdez '),
#  (337, 'James', 'Griffen '),
#  (338, 'Jason', 'Jordan '),
#  (339, 'Jennifer', 'Sees '),
#  (340, 'Judy', 'Stromme '),
#  (341, 'Wayne', 'Grist '),
#  (342, 'Lillian', 'Morrow '),
#  (343, 'Erica', 'Schmidt '),
#  (344, 'Mary', 'Mccormick '),
#  (345, 'Hubert', 'Halliday '),
#  (346, 'Barbara', 'Engle '),
#  (347, 'Samantha', 'Lam '),
#  (348, 'Richard', 'Serna '),
#  (349, 'Brenna', 'Cole '),
#  (350, 'Lindsey', 'Cross '),
#  (351, 'Sharlene', 'Woodruff '),
#  (352, 'Paula', 'Santiago '),
#  (353, 'Ryan', 'Murdock '),
#  (354, 'Helen', 'Conrad '),
#  (355, 'Dennis', 'Clark '),
#  (356, 'Laurie', 'Saunders '),
#  (357, 'Ray', 'Leek '),
#  (358, 'Steve', 'Perza '),
#  (359, 'Beatrice', 'Loveland '),
#  (360, 'Lawrence', 'Petrella '),
#  (361, 'Audrey', 'Mark '),
#  (362, 'Robert', 'Garcia '),
#  (363, 'Emily', 'Hill '),
#  (364, 'Maurice', 'Ford '),
#  (365, 'Bridgette', 'Burdine '),
#  (366, 'Katie', 'Lunde '),
#  (367, 'James', 'Holt '),
#  (368, 'Michelle', 'Collins '),
#  (369, 'Clara', 'Mckinney '),
#  (370, 'Kelly', 'Gibbs '),
#  (371, 'Michael', 'Moore '),
#  (372, 'Peggy', 'Sanderlin '),
#  (373, 'Lucille', 'Diaz '),
#  (374, 'Betty', 'Knowles '),
#  (375, 'Saundra', 'Gay '),
#  (376, 'Jeff', 'Albertson '),
#  (377, 'Marc', 'Ingram '),
#  (378, 'Susan', 'Resnick '),
#  (379, 'Lawrence', 'Walker '),
#  (380, 'Marie', 'Bradford '),
#  (381, 'Lucille', 'Conner '),
#  (382, 'Angela', 'Halasz '),
#  (383, 'Ivory', 'Willsey '),
#  (384, 'Alta', 'Martin '),
#  (385, 'Robert', 'Orchard '),
#  (386, 'Tyrone', 'Siegel '),
#  (387, 'Jayme', 'Gilchrest '),
#  (388, 'Gilbert', 'Hughley '),
#  (389, 'Mabel', 'Lee '),
#  (390, 'Melvin', 'Yanko '),
#  (391, 'Mary', 'Shouse '),
#  (392, 'Sandy', 'Lyons '),
#  (393, 'Margaret', 'Neal '),
#  (394, 'Jessica', 'Smith '),
#  (395, 'David', 'Wells '),
#  (396, 'Cheryle', 'Mayberry '),
#  (397, 'Gwendolyn', 'Burnette '),
#  (398, 'Cecilia', 'Thivierge '),
#  (399, 'Betty', 'Stark '),
#  (400, 'Jeffrey', 'Mckown '),
#  (401, 'Robert', 'Molina '),
#  (402, 'Alan', 'Holbrook '),
#  (403, 'Esther', 'Tecuanhuey '),
#  (404, 'Joshua', 'Davidson '),
#  (405, 'Dorothy', 'Jackson '),
#  (406, 'Megan', 'Guillen '),
#  (407, 'Pamela', 'Weathersby '),
#  (408, 'Michael', 'Lee '),
#  (409, 'Andreas', 'Halm '),
#  (410, 'Kenneth', 'Tomlinson '),
#  (411, 'Kathy', 'Defoor '),
#  (412, 'Richard', 'Oaks '),
#  (413, 'Frank', 'Kuennen '),
#  (414, 'Brian', 'Burns '),
#  (415, 'Janet', 'Thom '),
#  (416, 'Ryan', 'Johnson '),
#  (417, 'Benjamin', 'Price '),
#  (418, 'Earl', 'Roach '),
#  (419, 'Augusta', 'Cole '),
#  (420, 'David', 'Doughty '),
#  (421, 'Harriet', 'Miller '),
#  (422, 'Daniel', 'Skipper '),
#  (423, 'Beverly', 'Ocasio '),
#  (424, 'Timothy', 'Smith '),
#  (425, 'Charles', 'Eakins '),
#  (426, 'Kelly', 'Kauffman '),
#  (427, 'Cynthia', 'Perlman '),
#  (428, 'George', 'Thomas '),
#  (429, 'Dorris', 'Maynard '),
#  (430, 'David', 'Baker '),
#  (431, 'Tony', 'Roth '),
#  (432, 'Barbara', 'Lawson '),
#  (433, 'Elvin', 'Maier '),
#  (434, 'Lawrence', 'Fadden '),
#  (435, 'Jill', 'Augusto '),
#  (436, 'Ellis', 'Kelly '),
#  (437, 'Debra', 'Gatto '),
#  (438, 'Linda', 'Tellier '),
#  (439, 'Keith', 'Cashin '),
#  (440, 'Kristin', 'Collings '),
#  (441, 'Vivian', 'Mendoza '),
#  (442, 'Nellie', 'Bradley '),
#  (443, 'Jasper', 'Pyon '),
#  (444, 'Phyllis', 'Weaver '),
#  (445, 'Jeffrey', 'Baker '),
#  (446, 'David', 'Borja '),
#  (447, 'Albert', 'Montgomery '),
#  (448, 'David', 'Yates '),
#  (449, 'Lyle', 'Yazzie '),
#  (450, 'David', 'Russo '),
#  (451, 'Peggy', 'Linen '),
#  (452, 'Helen', 'Crabtree '),
#  (453, 'Robin', 'Andrews '),
#  (454, 'Ryan', 'Flamer '),
#  (455, 'Ross', 'Mcgeorge '),
#  (456, 'Lien', 'Miller '),
#  (457, 'Jewel', 'Alsup '),
#  (458, 'Bill', 'Rose '),
#  (459, 'Janet', 'Macdowell '),
#  (460, 'Marjorie', 'Shelton '),
#  (461, 'Byron', 'Glover '),
#  (462, 'Neil', 'Sales '),
#  (463, 'Fred', 'Healey '),
#  (464, 'Lauralee', 'Uselman '),
#  (465, 'Juanita', 'Crane '),
#  (466, 'Cheri', 'Tolbert '),
#  (467, 'Steven', 'Nivens '),
#  (468, 'Clara', 'Fitzgerald '),
#  (469, 'Jennifer', 'Tart '),
#  (470, 'Cristy', 'Lee '),
#  (471, 'Brittany', 'Fischer '),
#  (472, 'Bruno', 'Carter '),
#  (473, 'Deborah', 'Garcia '),
#  (474, 'Wayne', 'Noffsinger '),
#  (475, 'Donna', 'Williams '),
#  (476, 'Kimberly', 'Kinsinger '),
#  (477, 'Noelle', 'Brizuela '),
#  (478, 'Theresa', 'Bonner '),
#  (479, 'Eleanor', 'Schafer '),
#  (480, 'Fernando', 'Scribner '),
#  (481, 'Stacy', 'Davila '),
#  (482, 'Rochelle', 'Ramirez '),
#  (483, 'Luke', 'Mills '),
#  (484, 'Gloria', 'Oliver '),
#  (485, 'Irene', 'Reeves '),
#  (486, 'Dennis', 'Steller '),
#  (487, 'William', 'Gaytan '),
#  (488, 'Melba', 'Johnson '),
#  (489, 'Janice', 'Coello '),
#  (490, 'Anthony', 'Muscarella '),
#  (491, 'Emily', 'Walsh '),
#  (492, 'Gary', 'Burnham '),
#  (493, 'Naomi', 'Litton '),
#  (494, 'Alberta', 'Hatfield '),
#  (495, 'Danielle', 'Hanson '),
#  (496, 'Kathy', 'Kegley '),
#  (497, 'Bonnie', 'Dilliard '),
#  (498, 'Katherine', 'Plourde '),
#  (499, 'Timothy', 'Gardner '),
#  (500, 'Gladys', 'Martin '),
#  (501, 'Donald', 'Solomon '),
#  (502, 'Kate', 'Pena '),
#  (503, 'Milton', 'Longshore '),
#  (504, 'Mina', 'Casas '),
#  (505, 'Annette', 'Rosboril '),
#  (506, 'Cory', 'Ignacio '),
#  (507, 'Mark', 'Terman '),
#  (508, 'Jason', 'Schwein '),
#  (509, 'Ada', 'Wong '),
#  (510, 'Thelma', 'Mcfadden '),
#  (511, 'William', 'Gurke '),
#  (512, 'Virginia', 'Johnson '),
#  (513, 'Mary', 'Verley '),
#  (514, 'Guillermina', 'Hemrich '),
#  (515, 'Crystal', 'Schooley '),
#  (516, 'Jack', 'Boone '),
#  (517, 'Grace', 'Clinton '),
#  (518, 'Lucy', 'Soria '),
#  (519, 'Robert', 'Flinders '),
#  (520, 'Sabrina', 'Schulz '),
#  (521, 'Erin', 'Krenz '),
#  (522, 'Ramona', 'Hutching '),
#  (523, 'Olive', 'Buckley '),
#  (524, 'Phillip', 'Verity '),
#  (525, 'Melanie', 'Shiring '),
#  (526, 'Shirley', 'Hunt '),
#  (527, 'Harold', 'Sears '),
#  (528, 'Louis', 'Gilchrist '),
#  (529, 'Lee', 'Mead '),
#  (530, 'Allen', 'Johnson '),
#  (531, 'Russell', 'Simmons '),
#  (532, 'Helena', 'Zhang '),
#  (533, 'Francis', 'Nolan '),
#  (534, 'Alan', 'Brailey '),
#  (535, 'Robert', 'Tucker '),
#  (536, 'Charles', 'Gardner '),
#  (537, 'Iris', 'Brown '),
#  (538, 'Rachel', 'Miller '),
#  (539, 'Karen', 'Lanning '),
#  (540, 'Isabel', 'Luft '),
#  (541, 'Julie', 'Nielson '),
#  (542, 'Nicole', 'Baird '),
#  (543, 'Gary', 'Balk '),
#  (544, 'Melissa', 'Laur '),
#  (545, 'Sheena', 'Leitner '),
#  (546, 'Korey', 'Luera '),
#  (547, 'Pat', 'Najera '),
#  (548, 'Katharine', 'Dixson '),
#  (549, 'Loren', 'Patten '),
#  (550, 'Brad', 'Campbell '),
#  (551, 'David', 'Pilkinton '),
#  (552, 'Major', 'Himes '),
#  (553, 'Mack', 'Gilder '),
#  (554, 'Jose', 'Nixon '),
#  (555, 'Andrew', 'Bodrick '),
#  (556, 'Joshua', 'Cave '),
#  (557, 'Juana', 'Keene '),
#  (558, 'Steven', 'Wilusz '),
#  (559, 'Bonnie', 'Yarbrough '),
#  (560, 'Jenna', 'Betts '),
#  (561, 'Robert', 'Lowder '),
#  (562, 'Henrietta', 'Duren '),
#  (563, 'Ashley', 'Mccollum '),
#  (564, 'Lora', 'Mahan '),
#  (565, 'Rosario', 'Wade '),
#  (566, 'Filomena', 'Jones '),
#  (567, 'Steven', 'Holland '),
#  (568, 'Louise', 'Hines '),
#  (569, 'John', 'Lawrence '),
#  (570, 'Jeremy', 'Andres '),
#  (571, 'Jeffery', 'Scipioni '),
#  (572, 'Scott', 'Chalmers '),
#  (573, 'Kimberly', 'Maultsby '),
#  (574, 'Tracy', 'Cox '),
#  (575, 'Catalina', 'Holloway '),
#  (576, 'Eugene', 'Martin '),
#  (577, 'Geneva', 'Myers '),
#  (578, 'Anne', 'Woodbury '),
#  (579, 'James', 'Bellerose '),
#  (580, 'Vivian', 'Hester '),
#  (581, 'Maryann', 'Montoya '),
#  (582, 'Elma', 'Hollenbeck '),
#  (583, 'Jason', 'Looney '),
#  (584, 'Robert', 'Wiggins '),
#  (585, 'Antonio', 'Ogata '),
#  (586, 'Margaret', 'Dunn '),
#  (587, 'Kevin', 'Solano '),
#  (588, 'Stephen', 'Hunter '),
#  (589, 'Ethel', 'Barnett '),
#  (590, 'Micheal', 'Hardiman '),
#  (591, 'Barbara', 'Thompson '),
#  (592, 'Helen', 'Hall '),
#  (593, 'Christopher', 'Gaskill '),
#  (594, 'James', 'Thompson '),
#  (595, 'Eugene', 'Parker '),
#  (596, 'Robert', 'Ramos '),
#  (597, 'Jessica', 'Etter '),
#  (598, 'Fabian', 'Gonzales '),
#  (599, 'Michele', 'Gall '),
#  (600, 'Timothy', 'Jackson '),
#  (601, 'Harold', 'Mayberry '),
#  (602, 'Martin', 'Mcnair '),
#  (603, 'Maria', 'Webb '),
#  (604, 'Marilyn', 'Pedraza '),
#  (605, 'Christine', 'Allen '),
#  (606, 'Donna', 'Mitchell '),
#  (607, 'Andrew', 'Mcfadden '),
#  (608, 'Eugene', 'Ruiz '),
#  (609, 'Ruth', 'Mcginnes '),
#  (610, 'Betty', 'Harritt '),
#  (611, 'Elinor', 'Sutton '),
#  (612, 'Josephine', 'Dunlow '),
#  (613, 'Mary', 'Fields '),
#  (614, 'Lillian', 'Johnston '),
#  (615, 'Iris', 'Siegel '),
#  (616, 'Susan', 'Cruce '),
#  (617, 'James', 'Mckinney '),
#  (618, 'Grace', 'Blazer '),
#  (619, 'Carlos', 'Linthicum '),
#  (620, 'Julie', 'Meraz '),
#  (621, 'Homer', 'Jackson '),
#  (622, 'Elvera', 'Folsom '),
#  (623, 'Elizabeth', 'Cissell '),
#  (624, 'Irene', 'Rodriguez '),
#  (625, 'Robert', 'Moore '),
#  (626, 'Lance', 'Baker '),
#  (627, 'Ronald', 'Shutt '),
#  (628, 'Carroll', 'Ringstaff '),
#  (629, 'Clifford', 'Viesselman '),
#  (630, 'Frances', 'Hafferkamp '),
#  (631, 'Sherry', 'Valadez '),
#  (632, 'Bob', 'Simmons '),
#  (633, 'Sharon', 'Robinson '),
#  (634, 'Jerald', 'Mayberry '),
#  (635, 'Earl', 'Wilson '),
#  (636, 'Debbie', 'Robinson '),
#  (637, 'Leroy', 'Olson '),
#  (638, 'Clara', 'Starcher '),
#  (639, 'Lydia', 'Seely '),
#  (640, 'Wayne', 'Smith '),
#  (641, 'Maureen', 'Decastro '),
#  (642, 'Lester', 'Brown '),
#  (643, 'Anita', 'Kline '),
#  (644, 'Olivia', 'Wilkins '),
#  (645, 'Kyle', 'Watkins '),
#  (646, 'Martha', 'Ward '),
#  (647, 'Alyssa', 'Jackson '),
#  (648, 'Sabrina', 'Kriegel '),
#  (649, 'Kevin', 'Griggs '),
#  (650, 'Janie', 'Karalis '),
#  (651, 'Jessica', 'Friedman '),
#  (652, 'Brendan', 'Blanchard '),
#  (653, 'Lia', 'French '),
#  (654, 'Beth', 'Black '),
#  (655, 'Alicia', 'Torres '),
#  (656, 'Donna', 'Smith '),
#  (657, 'Marla', 'Smith '),
#  (658, 'James', 'Wilson '),
#  (659, 'Sheila', 'Degirolamo '),
#  (660, 'Anthony', 'Johnson '),
#  (661, 'Nicholas', 'Dodge '),
#  (662, 'Dylan', 'Garvin '),
#  (663, 'Courtney', 'Stewart '),
#  (664, 'Terry', 'Paine '),
#  (665, 'Brian', 'Harrison '),
#  (666, 'Barbara', 'Letko '),
#  (667, 'Steve', 'Hale '),
#  (668, 'Dorothy', 'Cardona '),
#  (669, 'Paulette', 'Madden '),
#  (670, 'Larry', 'Embry '),
#  (671, 'Bryan', 'Nash '),
#  (672, 'Marilynn', 'Cintron '),
#  (673, 'Wendy', 'Peden '),
#  (674, 'Steven', 'Lenz '),
#  (675, 'Michelle', 'Craft '),
#  (676, 'Jin', 'Beck '),
#  (677, 'Richard', 'Lawerence '),
#  (678, 'Mary', 'Schmidtke '),
#  (679, 'Clara', 'Hykes '),
#  (680, 'Hilda', 'Buffington '),
#  (681, 'Heather', 'Gutierrez '),
#  (682, 'Tamar', 'Peavy '),
#  (683, 'Carrie', 'Tachauer '),
#  (684, 'Judy', 'Dorsette '),
#  (685, 'Diana', 'Gonzalez '),
#  (686, 'Lindsey', 'Mcclinton '),
#  (687, 'Dennis', 'Holdman '),
#  (688, 'Jennifer', 'Sousa '),
#  (689, 'Jose', 'Reeder '),
#  (690, 'James', 'Clune '),
#  (691, 'Craig', 'Weidner '),
#  (692, 'Paul', 'Adkison '),
#  (693, 'Robert', 'Jose '),
#  (694, 'Janice', 'Brandt '),
#  (695, 'Christopher', 'Drexler '),
#  (696, 'Joseph', 'Durst '),
#  (697, 'Therese', 'Fuller '),
#  (698, 'Lloyd', 'Castellanos '),
#  (699, 'Wilbur', 'Tall '),
#  (700, 'Jose', 'Maglio '),
#  (701, 'Lindsey', 'Oshea '),
#  (702, 'Clara', 'Romano '),
#  (703, 'Vincent', 'Parrish '),
#  (704, 'Don', 'Landrum '),
#  (705, 'Lawrence', 'Merriman '),
#  (706, 'Carol', 'Ball '),
#  (707, 'James', 'Alvarado '),
#  (708, 'Nicole', 'Collins '),
#  (709, 'Louis', 'Moreland '),
#  (710, 'Ocie', 'Reed '),
#  (711, 'Donna', 'Masters '),
#  (712, 'Sarah', 'Coffin '),
#  (713, 'Paul', 'Roberts '),
#  (714, 'Steve', 'Mccool '),
#  (715, 'Jane', 'Moreno '),
#  (716, 'Juanita', 'Weathers '),
#  (717, 'Debbie', 'Bissonette '),
#  (718, 'Carlos', 'Griffin '),
#  (719, 'Leon', 'Groce '),
#  (720, 'Jan', 'Williams '),
#  (721, 'Joy', 'Cooper '),
#  (722, 'Edward', 'Brown '),
#  (723, 'Cecil', 'Canez '),
#  (724, 'Roger', 'Poling '),
#  (725, 'Patricia', 'Upright '),
#  (726, 'Russell', 'Rapp '),
#  (727, 'Michael', 'Thompson '),
#  (728, 'Felix', 'Stevens '),
#  (729, 'Allison', 'Shuman '),
#  (730, 'David', 'Saunders '),
#  (731, 'Elaine', 'Crossley '),
#  (732, 'Nu', 'Burgos '),
#  (733, 'Jeffrey', 'Graham '),
#  (734, 'John', 'Hart '),
#  (735, 'Kristen', 'Rios '),
#  (736, 'Mabel', 'Chan '),
#  (737, 'Jeffrey', 'Stuckett '),
#  (738, 'William', 'Kelly '),
#  (739, 'William', 'Arterburn '),
#  (740, 'William', 'Trexler '),
#  (741, 'Randall', 'Fulcher '),
#  (742, 'Edith', 'Ballard '),
#  (743, 'Shakia', 'Cameron '),
#  (744, 'Alison', 'Mejias '),
#  (745, 'Elliot', 'Singer '),
#  (746, 'Benjamin', 'Womack '),
#  (747, 'Ronnie', 'Nicole '),
#  (748, 'Joann', 'Larson '),
#  (749, 'Daniel', 'Rodriguez '),
#  (750, 'Frances', 'Price '),
#  (751, 'Brandon', 'Mccauley '),
#  (752, 'Toni', 'Thompson '),
#  (753, 'Peggy', 'Harrison '),
#  (754, 'Mark', 'Fugate '),
#  (755, 'Grant', 'Russell '),
#  (756, 'Peter', 'Williams '),
#  (757, 'Virginia', 'Johnson '),
#  (758, 'Veronica', 'Vranicar '),
#  (759, 'Maureen', 'Ortiz '),
#  (760, 'Becky', 'Wyatt '),
#  (761, 'Juan', 'Pannell '),
#  (762, 'George', 'Tidmore '),
#  (763, 'Theodore', 'Galloway '),
#  (764, 'Joyce', 'Gomez '),
#  (765, 'Norman', 'Hallam '),
#  (766, 'Sylvia', 'Decourcey '),
#  (767, 'Emma', 'Capuano '),
#  (768, 'John', 'Rogers '),
#  (769, 'Bobby', 'Bass '),
#  (770, 'Tina', 'Kelley '),
#  (771, 'Stewart', 'Gonzales '),
#  (772, 'Nathanial', 'Kalar '),
#  (773, 'Antonio', 'Browning '),
#  (774, 'Greg', 'Murphy '),
#  (775, 'Thomas', 'Andueza '),
#  (776, 'Jose', 'Simpson '),
#  (777, 'Robert', 'Tripp '),
#  (778, 'Rita', 'Stewart '),
#  (779, 'Silvia', 'Picciano '),
#  (780, 'Margie', 'Ray '),
#  (781, 'Thomas', 'Romero '),
#  (782, 'Iola', 'Ralph '),
#  (783, 'Jennifer', 'Cox '),
#  (784, 'Darryl', 'Garza '),
#  (785, 'Janell', 'Lopes '),
#  (786, 'Lois', 'Waters '),
#  (787, 'Mae', 'Underwood '),
#  (788, 'Leroy', 'Lemmon '),
#  (789, 'John', 'Knapp '),
#  (790, 'Ida', 'Kohn '),
#  (791, 'Joseph', 'Sosa '),
#  (792, 'Jason', 'Voss '),
#  (793, 'Wallace', 'Mcpherson '),
#  (794, 'Katie', 'Staats '),
#  (795, 'Patricia', 'Rodgers '),
#  (796, 'Jose', 'Tangri '),
#  (797, 'John', 'Daniel '),
#  (798, 'Kevin', 'Partington '),
#  (799, 'Kathryn', 'Munoz '),
#  (800, 'Isiah', 'Beer '),
#  (801, 'Irma', 'Baker '),
#  (802, 'Wanda', 'Wingate '),
#  (803, 'Coy', 'Green '),
#  (804, 'Luther', 'Wynn '),
#  (805, 'Kevin', 'Ferguson '),
#  (806, 'Willie', 'Avent '),
#  (807, 'Jeanette', 'Prindle '),
#  (808, 'Cynthia', 'Bohringer '),
#  (809, 'Duane', 'Lopez '),
#  (810, 'Linda', 'Herndon '),
#  (811, 'Derek', 'Braden '),
#  (812, 'Joyce', 'Patino '),
#  (813, 'Samuel', 'Kennedy '),
#  (814, 'Tina', 'Slough '),
#  (815, 'Lorraine', 'Tharp '),
#  (816, 'Earl', 'Walker '),
#  (817, 'Steven', 'Harrier '),
#  (818, 'Judy', 'Mcneely '),
#  (819, 'Jonathan', 'Pepper '),
#  (820, 'Marisol', 'Nations '),
#  (821, 'Robert', 'Larson '),
#  (822, 'Irene', 'Allen '),
#  (823, 'Richard', 'Proffer '),
#  (824, 'Mary', 'Garst '),
#  (825, 'Sharon', 'Hyder '),
#  (826, 'Neil', 'Paget '),
#  (827, 'Kimberly', 'Cowles '),
#  (828, 'Cindy', 'Cascio '),
#  (829, 'Anthony', 'Bolton '),
#  (830, 'Fred', 'Ladner '),
#  (831, 'Martha', 'Wang '),
#  (832, 'Mary', 'Watkins '),
#  (833, 'Corine', 'Hand '),
#  (834, 'Patricia', 'Mcelyea '),
#  (835, 'Bessie', 'Freeman '),
#  (836, 'Robert', 'Jackson '),
#  (837, 'Norman', 'Frank '),
#  (838, 'Sandra', 'Vanover '),
#  (839, 'Jerald', 'Lawson '),
#  (840, 'Albert', 'Szekely '),
#  (841, 'Tommy', 'Borja '),
#  (842, 'Christopher', 'Moore '),
#  (843, 'Derek', 'Buhmann '),
#  (844, 'Lance', 'Mcnally '),
#  (845, 'James', 'Hajek '),
#  (846, 'Troy', 'Wagner '),
#  (847, 'Randell', 'Woodlin '),
#  (848, 'Raymond', 'Burton '),
#  (849, 'Debra', 'Connelly '),
#  (850, 'Ricky', 'Wright '),
#  (851, 'Toni', 'Wadsworth '),
#  (852, 'Muriel', 'Richerson '),
#  (853, 'Tami', 'Harrington '),
#  (854, 'Lillian', 'Armbruster '),
#  (855, 'Betty', 'Edmond '),
#  (856, 'Ashley', 'Corbett '),
#  (857, 'Barbara', 'Fujisawa '),
#  (858, 'Walter', 'Bernstein '),
#  (859, 'Amber', 'Atkins '),
#  (860, 'Claudia', 'Carpenter '),
#  (861, 'Darrell', 'Johnson '),
#  (862, 'Gloria', 'Bates '),
#  (863, 'Bob', 'Doster '),
#  (864, 'Mildred', 'Hooten '),
#  (865, 'Robert', 'Alston '),
#  (866, 'Geraldine', 'Moon '),
#  (867, 'Robert', 'Cherry '),
#  (868, 'Doris', 'Gervais '),
#  (869, 'Cheryl', 'Whitson '),
#  (870, 'Larissa', 'Willis '),
#  (871, 'Mary', 'Bergesen '),
#  (872, 'Grace', 'Davis '),
#  (873, 'Rachel', 'Ellis '),
#  (874, 'Chauncey', 'Horton '),
#  (875, 'Pablo', 'Walton '),
#  (876, 'John', 'Arnold '),
#  (877, 'Linda', 'Fitzloff '),
#  (878, 'Thomas', 'Palmer '),
#  (879, 'Peter', 'Agnello '),
#  (880, 'Mathew', 'Crook '),
#  (881, 'James', 'Hawkins '),
#  (882, 'Sharon', 'Henry '),
#  (883, 'Harold', 'Jones '),
#  (884, 'Virginia', 'Glidden '),
#  (885, 'Cesar', 'Holt '),
#  (886, 'Mary', 'Shasteen '),
#  (887, 'Anthony', 'Byler '),
#  (888, 'Amy', 'Williams '),
#  (889, 'David', 'Heinrich '),
#  (890, 'Anthony', 'Riches '),
#  (891, 'Gina', 'Hastie '),
#  (892, 'Matthew', 'Cunningham '),
#  (893, 'Donald', 'Nester '),
#  (894, 'Marilyn', 'Azar '),
#  (895, 'George', 'Padilla '),
#  (896, 'Sandra', 'Warner '),
#  (897, 'Brenda', 'Muina '),
#  (898, 'Helen', 'Moten '),
#  (899, 'Christina', 'Cash '),
#  (900, 'Harry', 'Norstrand '),
#  (901, 'Eric', 'Simmons '),
#  (902, 'Pamela', 'Tartt '),
#  (903, 'Robert', 'Mccue '),
#  (904, 'Harvey', 'Campbell '),
#  (905, 'Tim', 'Mcgregor '),
#  (906, 'Warren', 'Fry '),
#  (907, 'Fernando', 'Poe '),
#  (908, 'Carol', 'French '),
#  (909, 'David', 'Sims '),
#  (910, 'Janice', 'Henshaw '),
#  (911, 'Evelyn', 'Johnson '),
#  (912, 'Andrew', 'Windham '),
#  (913, 'Roger', 'Hernandez '),
#  (914, 'Elizabeth', 'Chean '),
#  (915, 'Donald', 'Chavez '),
#  (916, 'Helen', 'Pierce '),
#  (917, 'Alan', 'Fay '),
#  (918, 'Jared', 'Conn '),
#  (919, 'Jon', 'Spaulding '),
#  (920, 'Christina', 'Jones '),
#  (921, 'Bonnie', 'Douglas '),
#  (922, 'Ella', 'Snider '),
#  (923, 'Phyllis', 'Mccray '),
#  (924, 'Ralph', 'Brizuela '),
#  (925, 'Diane', 'Mcgovern '),
#  (926, 'David', 'Burchess '),
#  (927, 'Bryan', 'Claridge '),
#  (928, 'Eric', 'Needham '),
#  (929, 'John', 'Ray '),
#  (930, 'Ruthann', 'Butler '),
#  (931, 'Lillian', 'Schmidt '),
#  (932, 'Laura', 'Guerrero '),
#  (933, 'Susan', 'Propst '),
#  (934, 'Patricia', 'Arvin '),
#  (935, 'Edward', 'Hansen '),
#  (936, 'Mary', 'Vogt '),
#  (937, 'Phyllis', 'Fitzgerald '),
#  (938, 'Annie', 'Lockhart '),
#  (939, 'Kimberly', 'Graham '),
#  (940, 'Tawana', 'Donley '),
#  (941, 'Bobbie', 'Rivas '),
#  (942, 'Thomas', 'Ortiz '),
#  (943, 'Betty', 'Wolf '),
#  (944, 'Matthew', 'Bunch '),
#  (945, 'Donna', 'Fraise '),
#  (946, 'Kyle', 'Travis '),
#  (947, 'Danielle', 'Bedford '),
#  (948, 'John', 'Corella '),
#  (949, 'Anna', 'Derosso '),
#  (950, 'Arnold', 'Mcmullen '),
#  (951, 'Maxine', 'Boothe '),
#  (952, 'Lorraine', 'Lewis '),
#  (953, 'Reed', 'Sotelo '),
#  (954, 'Robert', 'Mayo '),
#  (955, 'Herman', 'Chech '),
#  (956, 'Patricia', 'Turner '),
#  (957, 'Carl', 'League '),
#  (958, 'Robert', 'Saylor '),
#  (959, 'Lawrence', 'Merrill '),
#  (960, 'Edward', 'Hutchins '),
#  (961, 'Sara', 'Custer '),
#  (962, 'Joshua', 'Drake '),
#  (963, 'Phyllis', 'Doil '),
#  (964, 'Robin', 'Weaver '),
#  (965, 'William', 'May '),
#  (966, 'Jenee', 'Kittel '),
#  (967, 'Nathan', 'Hinson '),
#  (968, 'Sally', 'Russ '),
#  (969, 'Sandra', 'Doggett '),
#  (970, 'Muriel', 'Schroder '),
#  (971, 'Linh', 'Vitullo '),
#  (972, 'Christopher', 'Field '),
#  (973, 'Daniel', 'Gerber '),
#  (974, 'Robert', 'Bourgeois '),
#  (975, 'David', 'Strain '),
#  (976, 'Johnna', 'Pyle '),
#  (977, 'Dena', 'Lacoy '),
#  (978, 'Hope', 'Booker '),
#  (979, 'Ronald', 'Hensley '),
#  (980, 'Barbara', 'Phillips '),
#  (981, 'Lee', 'Williams '),
#  (982, 'Faye', 'Craig '),
#  (983, 'Amber', 'Bankston '),
#  (984, 'Ricardo', 'Jensen '),
#  (985, 'Jennie', 'Dockery '),
#  (986, 'Grover', 'Epstein '),
#  (987, 'Sammie', 'Robbins '),
#  (988, 'Becky', 'Mathews '),
#  (989, 'Mario', 'Tillman '),
#  (990, 'Colleen', 'Montgomery '),
#  (991, 'James', 'Downey '),
#  (992, 'Paul', 'Perrien '),
#  (993, 'David', 'Houck '),
#  (994, 'Misty', 'Woodard '),
#  (995, 'Gilberto', 'Ramirez '),
#  (996, 'Yasmin', 'Mcdonald '),
#  (997, 'Valerie', 'Palmer '),
#  (998, 'Roy', 'Riebau '),
#  (999, 'Kimberly', 'Johnson '),
#  (1000, 'Katrina', 'Frank ')]

# %% [markdown]
# ### Consulta 2 (6 pts)
# **Cantidad de personas nacidas después del inicio de la pandemia.**(inicio de la pandemia 01-12-2019)
#
# Ejemplo:
#
#
# | Cantidad     |
# |--------------|
# | 292 |
#
# **Solución:** Utilizamos el condicional where para que contara a las personas nacidas después de la pandemia, y dado que nacieron luego de que iniciara la pandemia, el día 01-12-2019 no contaría, solamente contarían los que nacieron luego de ese día.

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#      count(fecha_nacimiento) AS "Cantidad"
# FROM
#     personas
# WHERE
#     fecha_nacimiento > '01-12-2019'
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 1 rows affected.
# [(56,)]

# %% [markdown]
# ### Consulta 3 (6 pts)
# **ID, nombre, apellidos y saldo total de todas las personas**( Limitar a 20 filas para visualizar)
#
# Ejemplo:
#
# | ID    | Nombre | Apellido | Dinero |
# |----------------|--------|-|-|
# | 13 | Tommy | Miller | 12501 |
# | ... | ... | ... | ... |
#
# **Solución:** Usamos un INNER JOIN para poder 'unir' la información de la tabla persona y de la tabla cuentas_bancarias.

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     personas.id AS "ID",
#     personas.nombre AS "Nombre",
#     left(apellidos, position(' ' in apellidos)) AS "Apellido",
#     cuentas_bancarias.saldo AS "Dinero"
# FROM
#     personas INNER JOIN cuentas_bancarias ON personas.id = cuentas_bancarias.id_persona
# LIMIT
#     20
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 20 rows affected.
# [(4, 'Victoria', 'Stafford ', 2173),
#  (10, 'Julian', 'Kay ', 4548),
#  (17, 'Phillip', 'Newcomb ', 263),
#  (34, 'Lisa', 'Schmalz ', 8841),
#  (38, 'William', 'Starr ', 5452),
#  (60, 'Tommy', 'Noonan ', 2117),
#  (75, 'Kenneth', 'Goldstein ', 8755),
#  (81, 'Maria', 'Petrulis ', 7035),
#  (94, 'Maxine', 'Picou ', 8159),
#  (105, 'Melissa', 'Barry ', 395),
#  (110, 'Roger', 'Gebhart ', 7333),
#  (132, 'Gary', 'Robinson ', 7470),
#  (135, 'Carol', 'Keeling ', 2132),
#  (180, 'Rosa', 'Shelton ', 8742),
#  (190, 'Mary', 'Harris ', 5370),
#  (208, 'Raul', 'Rodriquez ', 5251),
#  (211, 'Rachel', 'Freeman ', 2284),
#  (216, 'Elizabeth', 'Limmel ', 2558),
#  (222, 'Cyril', 'Modica ', 8167),
#  (248, 'Derek', 'Emmons ', 3929)]

# %% [markdown]
# ### Consulta 4 (6 pts)
# **Nombre de la Facción y la cantidad de trabajadores activos hasta fecha X.**
#
# Ejemplo:
#
# | Facción     | Cantidad de trabajadores |
# |----------------|--------|
# | FEDRA | 1273 |
# | Luciérnagas | 121 |
# | Carroñeros  | 72 |
# | ...  | ... |
#
# **Solución:** Usamos INNER JOIN para crear una integración de información de los trabajadores activos y su facción, luego realizamos un COUNT() para contar el total.

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     facciones.nombre AS "Facción",
#     COUNT(facciones.nombre) AS "Cantidad de trabajadores"
# FROM
#     facciones
#     INNER JOIN persona_pertenece_faccion ON facciones.id = persona_pertenece_faccion.id_faccion
#     INNER JOIN personas ON persona_pertenece_faccion.id_persona = personas.id
#     INNER JOIN persona_tiene_trabajo ON personas.id = persona_tiene_trabajo.id_persona WHERE estado = True
# GROUP BY
#     facciones.nombre
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 6 rows affected.
# [('JavaScriptia', 9),
#  ('Pythonia', 6),
#  ('MaCdonia', 11),
#  ('FEDRA', 10),
#  ('Luciérnagas', 7),
#  ('Carroñeros', 5)]

# %% [markdown]
# ### Consulta 5 (6 pts)
# **Nombre de la Facción y su cantidad de personas infectadas.**
#
# Ejemplo:
#
# |  Facción  | Personas infectadas |
# |--------|-------|
# | FEDRA | 251 |
# | Luciérnagas | 17 |
# | Carroñeros  | 12 |
# | ...  | ... |
#
# **Solución:** Hicimos INNER JOIN entre la tabla de las personas, de las facciones y de las personas_pertenecen_faccion para rescatar si esta infectado o no y su faccion correspondiente. Luego agrupamos según faccion.

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     facciones.nombre AS Faccion,
#     COUNT (*) AS personas_infectadas
# FROM
#     facciones INNER JOIN persona_pertenece_faccion ON facciones.id = persona_pertenece_faccion.id_faccion
#     INNER JOIN personas ON persona_pertenece_faccion.id_persona = personas.id WHERE infectado = True
# GROUP BY (facciones.nombre, personas.infectado)
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 6 rows affected.
# [('Carroñeros', 22),
#  ('Pythonia', 14),
#  ('Luciérnagas', 24),
#  ('FEDRA', 25),
#  ('JavaScriptia', 15),
#  ('MaCdonia', 30)]

# %% [markdown]
# ### Consulta 6 (6 pts)
# **Nombre de la Facción y su trabajo más realizado.**
#
# Ejemplo:
#
# |  Facción  | Trabajo |
# |--------|-------|
# | FEDRA | Limpiador de cloacas |
# | Luciérnagas | Médico |
# | Carroñeros  | Explorador |
# | ...  | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     facciones.nombre AS faccion,
#     trabajos.nombre,
#     COUNT(trabajos.nombre)
# FROM
#     facciones INNER JOIN persona_pertenece_faccion ON facciones.id = persona_pertenece_faccion.id_faccion
#     INNER JOIN personas ON persona_pertenece_faccion.id_persona = personas.id
#     INNER JOIN persona_tiene_trabajo ON personas.id = persona_tiene_trabajo.id_persona
#     INNER JOIN trabajos ON persona_tiene_trabajo.id_trabajo = trabajos.id
# GROUP BY
#     facciones.nombre, trabajos.nombre
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 49 rows affected.
# [('FEDRA', 'Limpieza', 1),
#  ('Luciérnagas', 'Cerrajero', 1),
#  ('Luciérnagas', 'Militar', 1),
#  ('JavaScriptia', 'Científico', 3),
#  ('Luciérnagas', 'Médico', 1),
#  ('MaCdonia', 'Cajero', 5),
#  ('Pythonia', 'Médico', 1),
#  ('Luciérnagas', 'Carpintero', 2),
#  ('Pythonia', 'Carpintero', 3),
#  ('JavaScriptia', 'Explorador', 2),
#  ('MaCdonia', 'Cerrajero', 3),
#  ('FEDRA', 'Limpiador de cloacas', 1),
#  ('Carroñeros', 'Limpieza', 1),
#  ('Carroñeros', 'Científico', 1),
#  ('Pythonia', 'Cajero', 2),
#  ('Luciérnagas', 'Científico', 2),
#  ('MaCdonia', 'Médico', 1),
#  ('JavaScriptia', 'Cajero', 1),
#  ('FEDRA', 'Cremador', 1),
#  ('FEDRA', 'Cartero', 1),
#  ('Pythonia', 'Limpiador de cloacas', 1),
#  ('FEDRA', 'Militar', 2),
#  ('Pythonia', 'Profesor', 1),
#  ('FEDRA', 'Explorador', 3),
#  ('FEDRA', 'Cerrajero', 3),
#  ('MaCdonia', 'Limpiador de cloacas', 1),
#  ('JavaScriptia', 'Médico', 1),
#  ('FEDRA', 'Científico', 2),
#  ('Carroñeros', 'Limpiador de cloacas', 3),
#  ('FEDRA', 'Cajero', 2),
#  ('Carroñeros', 'Cajero', 1),
#  ('Luciérnagas', 'Cajero', 2),
#  ('MaCdonia', 'Carpintero', 2),
#  ('MaCdonia', 'Cartero', 1),
#  ('MaCdonia', 'Explorador', 2),
#  ('Luciérnagas', 'Limpiador de cloacas', 1),
#  ('JavaScriptia', 'Limpieza', 1),
#  ('Pythonia', 'Militar', 1),
#  ('Carroñeros', 'Carpintero', 1),
#  ('FEDRA', 'Carpintero', 1),
#  ('JavaScriptia', 'Militar', 2),
#  ('Carroñeros', 'Cerrajero', 3),
#  ('JavaScriptia', 'Cerrajero', 1),
#  ('Luciérnagas', 'Cocinero', 2),
#  ('JavaScriptia', 'Carpintero', 1),
#  ('Carroñeros', 'Militar', 1),
#  ('FEDRA', 'Profesor', 1),
#  ('Luciérnagas', 'Cremador', 1),
#  ('MaCdonia', 'Profesor', 1)]

# %% [markdown]
# ### Consulta 7 (8 pts)
# **Nombre de la Facción y su Saldo total** (Es decir, la suma total de los saldos de cada persona perteneciente a la facción.)
#
# Ejemplo:
#
# |Facción | Saldo |
# |--------|-|
# | FEDRA | 523000 |
# | Luciérnagas | 130023 |
# | Carroñeros  | 17432 |
# | ...  | ...|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     facciones.nombre AS faccion,
#     SUM(cuentas_bancarias.saldo) AS saldo
# FROM
#     facciones INNER JOIN persona_pertenece_faccion ON facciones.id = persona_pertenece_faccion.id_faccion
#     INNER JOIN personas ON persona_pertenece_faccion.id_persona = personas.id
#     INNER JOIN cuentas_bancarias ON personas.id = cuentas_bancarias.id_persona
# GROUP BY
#     facciones.nombre, saldo
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 31 rows affected.
# [('FEDRA', 6922),
#  ('Pythonia', 2672),
#  ('FEDRA', 7035),
#  ('Pythonia', 4967),
#  ('FEDRA', 3406),
#  ('FEDRA', 5242),
#  ('FEDRA', 1220),
#  ('Luciérnagas', 2639),
#  ('MaCdonia', 9125),
#  ('Carroñeros', 8841),
#  ('Pythonia', 1899),
#  ('Luciérnagas', 133),
#  ('JavaScriptia', 8448),
#  ('Luciérnagas', 9087),
#  ('JavaScriptia', 2117),
#  ('Luciérnagas', 5495),
#  ('JavaScriptia', 6962),
#  ('Luciérnagas', 2917),
#  ('MaCdonia', 9961),
#  ('Carroñeros', 7208),
#  ('Carroñeros', 2672),
#  ('JavaScriptia', 5616),
#  ('MaCdonia', 532),
#  ('FEDRA', 9549),
#  ('Carroñeros', 1733),
#  ('Luciérnagas', 323),
#  ('Pythonia', 2117),
#  ('Pythonia', 7393),
#  ('JavaScriptia', 8167),
#  ('FEDRA', 9382),
#  ('MaCdonia', 5616)]

# %% [markdown]
# ### Consulta 8 (6 pts)
# **Nombre del Banco, cantidad de usuarios pertenecientes al banco y saldo total del banco.**
#
# ###### Es decir, todos los bancos que ocupan los habitantes de cada faccion
#
# Ejemplo:
#
# |Banco | Cantidad|Saldo|
# |----|---|---|
# |FedraBank S.A |321|20000|
# |Banco Pedrito Pascal SpA  |21|200|
# | Banco De Chile|213|56000|
# | ... | ... |
#
# **Solución:** Usamos un INNER JOIN para 'intersectar' la información de la tabla personas y cuentas_bancarias, luego sumamos los saldos con SUM() y contamos la cantidad de usuarios con COUNT().

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     cuentas_bancarias.banco AS "Banco",
#     COUNT(*) AS "Cantidad",
#     SUM(cuentas_bancarias.saldo) AS "Saldo"
# FROM
#     cuentas_bancarias INNER JOIN personas ON cuentas_bancarias.id_persona = personas.id
# GROUP BY (cuentas_bancarias.banco)
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 10 rows affected.
# [('Banco Consorcio S.A', 10, 61482),
#  ('Banco de la Nación S.A', 11, 62308),
#  ('Banco Santander SpA', 11, 39473),
#  ('Banco Pythonia S.A', 9, 40842),
#  ('Banco BCI SpA', 12, 65400),
#  ('FedraBank S.A', 16, 72867),
#  ('Banco BBVA', 14, 69316),
#  ('Banco Estado SpA', 14, 73313),
#  ('Banco Pedrito Pascal SpA', 13, 77144),
#  ('Banco Scotiabank', 10, 40660)]

# %% [markdown]
# ### Consulta 9 (8 pts)
# **Nombre de la Facción y el Banco más utilizado por sus habitantes**(Si hay empate, que se muestre solo uno.)
#
# Ejemplo:
#
# |Facción | Banco |
# | - | - |
# | FEDRA | FedraBank S.A |
# | Luciérnagas | Banco Pedrito Pascal SpA |
# | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 10 (6 pts)
# **ID, nombre y segundo apellido de las personas traidoras**(Es decir, si la persona pertenece a dos o más facciones.)
#
# Ejemplo:
#
# |ID | Nombre | Apellido |
# |-|-------|-|
# | 1 | Pedro | Pascal |
# | 2 | Bella | Ramsey |
# | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta BONUS (6 pts.)
#
# **Nombre y Apellidos de las personas casadas**(solo se muestra una única vez la pareja)
#
# Ejemplo:
#
# |Nombre persona 1 | Apellidos persona 1 | Nombre persona 2 | Apellidos persona 2 |
# |-|-------|-|-|
# | Felipe | Martinez | Raul | Cuello |
# | Rodrigo | Munita | Juan | Mira |
# | Nicole | Rojel | Benjamin | Campos |
# | ... | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *
